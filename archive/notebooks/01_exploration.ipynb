# %% [markdown]
# # World Cup predictor exploration
#
# This notebook reads pipeline outputs only. Feature construction and modeling remain in `src/`.

# %%
from pathlib import Path
import pandas as pd

ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
features_path = ROOT / 'data' / 'processed' / 'match_features.csv'
features = pd.read_csv(features_path, parse_dates=['date'])
features.shape

# %%
features[['home_score', 'away_score', 'elo_diff', 'neutral']].describe()

# %%
features.assign(year=features['date'].dt.year).groupby('year').size().tail(20).plot(title='Matches per year')
